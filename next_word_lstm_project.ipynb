# %% [markdown]
# # Next Word Predictor - LSTM
# <img src="output.png">

# %%
github_copilot_faqs = """This guide describes the most common issues with GitHub Copilot and how to resolve them. We've also shared some important details about the latest developments in the world of Copilot 🤖

We love all the questions you ask in the community and wanted to answer some of the frequently asked questions related to GitHub Copilot. We know your time is valuable so before jumping into the FAQs, there are two a few easy checks that you should tick off.

Tip

1️⃣ For questions about the general use of GitHub Copilot, product impact, human, oversight, and privacy, see the comprehensive list of GitHub Copilot FAQs.
2️⃣ If GitHub Copilot stops working, check GitHub's Status page for any active incidents.

⚡ Quick Updates
GitHub Copilot Workspace - a key milestone in our vision to redefine developer landscape, is now in public beta. Sign up now!
Copilot Enterprise is generally available and is customized to your organization’s knowledge and codebase.
GitHub Copilot Chat is now generally available in JetBrains IDE. Please share your feedback or ideas on how to improve the product in this discussion.
Copilot Chat in GitHub Mobile is coming soon. 🔜
Copilot content exclusions feature is Live! (re-deployed). Learn more
Copilot in CLI is now generally available. Find out more in this post.
Important

Please create a new discussion in the Copilot category if you have any questions or feedback regarding GitHub Copilot. You'll have much better chances of getting a response from the community including staff members. Thanks!

👀 GitHub Copilot Chat now generally available 🤖
GitHub Copilot Chat is generally available for organizations and individuals. This offering is also available at no cost to verified teachers, students, and maintainers of popular open source projects. For more details, see this announcement. Key Universe 2023 updates to Copilot Chat:

Copilot Chat has been made generally available to JetBrains IDE, please refer this discussion for steps to get started and sharing your feedback about the new experience.
Copilot Chat is now powered by GPT-4, bringing more accurate code suggestions and explanations with OpenAI’s GPT-4 model.
Are you interested to explore Copilot Workspace where you can simplify the process of making repo-wide edits, using verifiable AI-generated plans and code? Find our more!
⚙️ Troubleshoot common issues with Copilot Chat
Unable to use the GitHub Copilot extension in the IDE ❓
We recommend you follow the quickstart guide for GitHub Copilot while setting up GitHub Copilot on your machine. For more information, see "Quickstart for GitHub Copilot."

The GitHub Copilot extension is frequently updated to fix bugs and add new features. It's important to keep your extension up to date because older clients cannot communicate with the GitHub Copilot servers. Update your GitHub Copilot extension on all the machines you have it installed. For more information about configuring GitHub Copilot in a supported IDE, see "Configuring GitHub Copilot."

Copilot Chat features aren't working for me in VSCode? ❓
Check each requirement if Copilot Chat doesn't work:

Make sure you are on the latest version of Visual Studio Code (run Code: Check for Updates).
Make sure you have the latest version of both the GitHub Copilot and GitHub Copilot Chat extensions.
Your GitHub account that is signed into VS Code must have an active Copilot subscription. Check your Copilot subscription.
Ensure that Copilot Chat is correctly setup. See the setup guide.
For more details, please refer the Getting started with GitHub Copilot Chat in VS Code guide.

Error: "GitHub Copilot could not connect to server. Extension activation failed" ❓
This error indicates that you either do not have a GitHub Copilot subscription, or there was an error connecting to the GitHub API to request a token to use GitHub Copilot.

To request another token from api.github.com, try signing in and out of GitHub Copilot from your IDE. Once you've logged out, GitHub Copilot will prompt you to sign back in.

If you still cannot connect to the server, you can create a discussion in our discussion forum. You can include log files from your IDE to help us troubleshoot the issue.

For more information, see the information about log files in the client-specific articles under "Troubleshooting GitHub Copilot."

Getting error "Invalid copilot token: missing token: 403 - GitHub Copilot could not connect to server. Extension activation failed: At this time, Copilot is not available in your location" ❓
Due to current trade controls, your GitHub account might be restricted from making use of Copilot. This is a region-based restriction and applies to all users located in some trade-restricted countries, being flagged for the same earlier reasons, and is separate from other GitHub services. Read more about it here:

GitHub and Trade Controls

If you feel this should not be the case, feel free to contact our Support team and open a ticket with them.

I have privacy and security related questions for GitHub Copilot. I want to get clarity about the usage terms of GitHub Copilot. 👀
Well, we're happy to answer all your questions. Please make your familiar with the existing resources:

Privacy – Copilot for Individuals
Privacy – Copilot for Business - We're building some exciting "GitHub Copilot Trust Center"
GitHub Copilot Product Specific Terms
GitHub Copilot Pre-release Terms
If you still have any questions, feel free to post them in the Copilot community

GitHub Copilot not suggesting multiple lines of code 👀
This is a known issue and our team is working towards a fix. For more information, see this comment on a GitHub Community discussion.

How do I get a refund for my Copilot subscription? ❓
We now have the option to self-serve refunds for Copilot. Please head over to the Help with your GitHub account section and save yourself some time.

Note that, in most cases, the Virtual Agent may be able to offer an immediate refund. But, if your concern is not resolved, you can always use the contact form to get in touch with our billing team.

Got other questions? Feel free to ask them in the community. 🚀
"""

# %%
import re


def remove_emojis(text):
    # Define the emoji pattern to include sequences as well
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
                               u"\U0001FA00-\U0001FA6F"  # Extended-A
                               u"\U0001FA70-\U0001FAFF"  # Extended-B
                               u"\u2600-\u26FF"          # Miscellaneous Symbols
                               u"\u2700-\u27BF"          # Dingbats
                               u"\u2B50"                 # Star
                               u"\u2934-\u2935"          # Arrows
                               u"\u2B05-\u2B07"
                               u"\u2B1B"                 # Black Large Square
                               u"\u3030"                 # Wavy Dash
                               u"\u303D"                 # Part Alternation Mark
                               u"\u3297"                 # Circled Ideograph Congratulation
                               u"\u3299"                 # Circled Ideograph Secret
                               u"0-9\ufe0f\u20e3"       # Digits and Combining Enclosing Keycap
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)


# Split the data into lines
lines = github_copilot_faqs.split('\n')

# Remove emojis from each line
cleaned_lines = [remove_emojis(line) for line in lines]

# Join the cleaned lines back into a string
cleaned_data = '\n'.join(cleaned_lines)

# Print the cleaned data
print(cleaned_data)
# Out:
# This guide describes the most common issues with GitHub Copilot and how to resolve them. We've also shared some important details about the latest developments in the world of Copilot
#
# We love all the questions you ask in the community and wanted to answer some of the frequently asked questions related to GitHub Copilot. We know your time is valuable so before jumping into the FAQs, there are two a few easy checks that you should tick off.
#
# Tip
#
#  For questions about the general use of GitHub Copilot, product impact, human, oversight, and privacy, see the comprehensive list of GitHub Copilot FAQs.
#  If GitHub Copilot stops working, check GitHub's Status page for any active incidents.
#
#  Quick Updates
# GitHub Copilot Workspace - a key milestone in our vision to redefine developer landscape, is now in public beta. Sign up now!
# Copilot Enterprise is generally available and is customized to your organization’s knowledge and codebase.
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([cleaned_data])

# %%
len(tokenizer.word_index)
# Out:
# 375

# %%
input_sequences = []
for sentence in cleaned_data.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[14, 39],
#  [14, 39, 135],
#  [14, 39, 135, 3],
#  [14, 39, 135, 3, 78],
#  [14, 39, 135, 3, 78, 79],
#  [14, 39, 135, 3, 78, 79, 80],
#  [14, 39, 135, 3, 78, 79, 80, 16],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51, 4],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51, 4, 136],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51, 4, 136, 40],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51, 4, 136, 40, 137],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51, 4, 136, 40, 137, 81],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51, 4, 136, 40, 137, 81, 138],
#  [14, 39, 135, 3, 78, 79, 80, 16, 2, 1, 6, 51, 4, 136, 40, 137, 81, 138, 33],
#  [14,
#   39,
#   135,
#   3,
#   78,
#   79,
#   80,
#   16,
#   2,
#   1,
#   6,
#   51,
#   4,
#   136,
#   40,
#   137,
#   81,
#   138,
#   33,
#   52],
#  [14,
#   39,
# ...

# %%
max_len = max([len(x) for x in input_sequences])
max_len
# Out:
# 61

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  14,  39],
#        [  0,   0,   0, ...,  14,  39, 135],
#        [  0,   0,   0, ...,  39, 135,   3],
#        ...,
#        [  0,   0,   0, ...,  82,  40,   5],
#        [  0,   0,   0, ...,  40,   5,   3],
#        [  0,   0,   0, ...,   5,   3,  34]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (939, 60)

# %%
y.shape
# Out:
# (939,)

# %%
len(tokenizer.word_index)
# Out:
# 375

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=376)

# %%
y.shape
# Out:
# (939, 376)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(376, 100, input_length=max_len - 1))
model.add(LSTM(200))
model.add(Dense(376, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 60, 100)           37600
#
#  lstm (LSTM)                 (None, 200)               240800
#
#  dense (Dense)               (None, 376)               75576
#
# ...
# Total params: 353976 (1.35 MB)
# Trainable params: 353976 (1.35 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 9s 166ms/step - loss: 5.7089 - accuracy: 0.0458
# Epoch 2/100
# 30/30 [==============================] - 4s 153ms/step - loss: 5.3351 - accuracy: 0.0490
# Epoch 3/100
# 30/30 [==============================] - 3s 109ms/step - loss: 5.2523 - accuracy: 0.0554
# Epoch 4/100
# 30/30 [==============================] - 1s 47ms/step - loss: 5.2046 - accuracy: 0.0554
# Epoch 5/100
# 30/30 [==============================] - 1s 48ms/step - loss: 5.1404 - accuracy: 0.0671
# Epoch 6/100
# 30/30 [==============================] - 1s 36ms/step - loss: 5.0490 - accuracy: 0.0852
# Epoch 7/100
# 30/30 [==============================] - 1s 31ms/step - loss: 4.9306 - accuracy: 0.1182
# Epoch 8/100
# 30/30 [==============================] - 1s 20ms/step - loss: 4.7543 - accuracy: 0.1257
# Epoch 9/100
# 30/30 [==============================] - 1s 19ms/step - loss: 4.5386 - accuracy: 0.1459
# Epoch 10/100
# ...

# %%
import time
import numpy as np

text = "what is Github copilot"

for i in range(20):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=max_len-1, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 0s 387ms/step
# what is Github copilot chat
# 1/1 [==============================] - 0s 19ms/step
# what is Github copilot chat is
# 1/1 [==============================] - 0s 18ms/step
# what is Github copilot chat is now
# 1/1 [==============================] - 0s 20ms/step
# what is Github copilot chat is now generally
# 1/1 [==============================] - 0s 20ms/step
# what is Github copilot chat is now generally available
# 1/1 [==============================] - 0s 29ms/step
# what is Github copilot chat is now generally available in
# 1/1 [==============================] - 0s 18ms/step
# what is Github copilot chat is now generally available in jetbrains
# 1/1 [==============================] - 0s 19ms/step
# what is Github copilot chat is now generally available in jetbrains ide
# 1/1 [==============================] - 0s 19ms/step
# what is Github copilot chat is now generally available in jetbrains ide please
# ...

# %%
# tokenizer.word_index

# %%
import ipywidgets as widgets
from IPython.display import display

# Define the function to preprocess and predict the next word
def predict_next_word(change):
    # Get the text from the input field
    text = change.new

    # Remove emojis
    text = remove_emojis(text)

    # Tokenize
    token_text = tokenizer.texts_to_sequences([text])[0]
    # Padding
    padded_token_text = pad_sequences([token_text], maxlen=max_len - 1, padding='pre')
    # Predict
    pos = np.argmax(model.predict(padded_token_text))

    for word, index in tokenizer.word_index.items():
        if index == pos:
            # Append the predicted next word to the input text
            output_text.value = text + " " + word

# Create widgets
text_input = widgets.Text(description="Enter a sentence:")
output_text = widgets.Text(description="Next Word:", disabled=True)

# Attach event handler to observe changes in the text input
text_input.observe(predict_next_word, names='value')

# Display widgets
display(text_input)
display(output_text)
# Out:
# Text(value='', description='Enter a sentence:')
# Text(value='', description='Next Word:', disabled=True)
# ...
# 1/1 [==============================] - 0s 30ms/step
